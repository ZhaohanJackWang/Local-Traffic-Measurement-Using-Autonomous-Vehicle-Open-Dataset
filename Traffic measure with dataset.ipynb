# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import geopandas as gpd
import os
import seaborn as sns

# %%
if os.path.isfile("final_data (complete) 18sec.xlsx"):
    filepath = "final_data (complete) 18sec.xlsx"
sample1 = pd.read_excel(filepath)
sample1.head()
# Out:
#    Unnamed: 0    q (veh/h)  k (veh/km)   v (km/h)  d (Analysis Distance in m)  \
# 0           0  3501.168267   67.845112  62.061344                   58.188161
# 1           1  3505.759648   67.816088  62.094852                   58.206969
# 2           2  3506.365859   67.789240  62.088844                   58.224419
# 3           3  3501.105685   67.764516  62.025013                   58.240575
# 4           4  3513.393213   67.740839  62.131205                   58.255946
#
#    x (AV Distance in m)  Frame  Time (s)  AV Cumulative Distance (m)  \
# 0              1.720620      2       0.1                    1.720620
# 1              1.724383      3       0.2                    3.445003
# 2              1.724872      4       0.3                    5.169875
# 3              1.720529      5       0.4                    6.890405
# 4              1.730331      6       0.5                    8.620735
#
#            k*v     % diff  Vehicle Count
# ...

# %%
df = pd.DataFrame(sample1, columns=["q (veh/h)", "Time (s)"])
c=df["q (veh/h)"]
df.plot.scatter(x="Time (s)", y="q (veh/h)", figsize=(20,12), c=c, cmap = 'winter_r');

# %%
df = pd.DataFrame(sample1, columns=["k (veh/km)", "Time (s)"])
c=df["k (veh/km)"]
df.plot.scatter(x="Time (s)", y="k (veh/km)", figsize=(20,12),c=c, cmap = 'winter_r');

# %%
df = pd.DataFrame(sample1, columns=["v (km/h)", "Time (s)"])
c=df["v (km/h)"]
df.plot.scatter(x="Time (s)", y="v (km/h)", figsize=(20,12),c=c, cmap = 'winter_r');

# %%
df = pd.DataFrame(sample1, columns=["q (veh/h)", "AV Cumulative Distance (m)", "Time (s)"])
c=df["q (veh/h)"]
df.plot.scatter(x="Time (s)", y="AV Cumulative Distance (m)", figsize=(20,12), c=c, cmap = 'winter_r');

# %%
df = pd.DataFrame(sample1, columns=["k (veh/km)", "AV Cumulative Distance (m)", "Time (s)"])
c=df["k (veh/km)"]
df.plot.scatter(x="Time (s)", y="AV Cumulative Distance (m)", figsize=(20,12), c=c, cmap = 'winter');

# %%
df = pd.DataFrame(sample1, columns=["v (km/h)", "AV Cumulative Distance (m)", "Time (s)"])
c=df["v (km/h)"]
df.plot.scatter(x="Time (s)", y="AV Cumulative Distance (m)", figsize=(20,12), c=c, cmap = 'winter_r');
